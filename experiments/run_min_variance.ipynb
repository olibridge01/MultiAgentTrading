# %%
import sys
# import os
sys.path.append('/Users/isaacwatson/Documents/MSc CSML/COMP0124/research-project/MultiAgentTrading/')

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
from strategies.min_variance import MinVariance
    
returns = pd.DataFrame({
    "stock1": np.random.uniform(-0.1,0.1,100),
    "stock2": np.random.uniform(-0.1,0.1,100),
    "stock3": np.random.uniform(-0.1,0.1,100),
})
    
min_variance = MinVariance(returns)

# %%
for t in range(1,returns.shape[0]):
    min_variance.returns = returns.iloc[:t]
    min_variance.get_allocation()
    min_variance.update_balance()
    min_variance.get_portfolio_value()

min_variance.plot_portfolio_value()
portfolio_value_history = min_variance.portfolio_value_history
# Out:
# /Users/isaacwatson/anaconda3/envs/multi-agent-trading/lib/python3.11/site-packages/pandas/core/frame.py:11198: RuntimeWarning: Degrees of freedom <= 0 for slice
#   base_cov = np.cov(mat.T, ddof=ddof)
# /Users/isaacwatson/anaconda3/envs/multi-agent-trading/lib/python3.11/site-packages/numpy/lib/function_base.py:2748: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /Users/isaacwatson/anaconda3/envs/multi-agent-trading/lib/python3.11/site-packages/numpy/lib/function_base.py:2748: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)

# %%
from utils.portfolio_performance import PortfolioPerformance

# %%
performance = PortfolioPerformance(portfolio_value_history)

# %%
performance.annualized_return()
# Out:
# 0.7822243499000701

# %%
performance.annualized_std()
# Out:
# 0.47072681833822444

# %%
performance.sharpe_ratio()
# Out:
# 1.6617373802102557
